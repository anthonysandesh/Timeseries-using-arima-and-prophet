# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score

# load the data
data = pd.read_csv('/Users/anthony/Desktop/INTONE/Time series(VPN)/Cisco Meraki Logs[22]/network_events_202211181302.csv')

df = data.loc[(data['type'] == 'events_dropped2') | (data['type'] == 'web_cache_stopped') | (data['type'] == 'ids_error')]
df
# Out:
# /var/folders/p2/05zzb9jx10x6f3chs84fjng80000gn/T/ipykernel_30627/131912053.py:8: DtypeWarning: Columns (7,8,10,12,14,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/Users/anthony/Desktop/INTONE/Time series(VPN)/Cisco Meraki Logs[22]/network_events_202211181302.csv')
#                    networkId             type     description clientId  \
# 949     N_667095694804410110  events_dropped2  Events dropped  k06ff6e
# 1180    N_667095694804410110  events_dropped2  Events dropped  k06ff6e
# 1181    N_667095694804410110  events_dropped2  Events dropped      NaN
# 1654    N_667095694804410110  events_dropped2  Events dropped  k06ff6e
# 2290    N_667095694804410110  events_dropped2  Events dropped  k528f05
# ...                      ...              ...             ...      ...
# 436545  N_667095694804410110  events_dropped2  Events dropped      NaN
# 436546  N_667095694804410110  events_dropped2  Events dropped  kb18b3a
# 436551  N_667095694804410110  events_dropped2  Events dropped      NaN
# 436552  N_667095694804410110  events_dropped2  Events dropped  k528f05
# 436571  N_667095694804410110  events_dropped2  Events dropped  kb18b3a
#
#                            clientDescription    deviceSerial  deviceName  \
# 949                                  Android  Q2PN-AH88-6CK7         NaN
# 1180                                 Android  Q2PN-AH88-6CK7         NaN
# 1181                                     NaN  Q2PN-AH88-6CK7         NaN
# 1654                                 Android  Q2PN-AH88-6CK7         NaN
# 2290                       be:7d:2c:c5:42:f0  Q2PN-AH88-6CK7         NaN
# ...                                      ...             ...         ...
# 436545                                   NaN  Q2PN-AH88-6CK7         NaN
# 436546  ea7860b8-a41d-4753-9667-40817b10f15c  Q2PN-AH88-6CK7         NaN
# 436551                                   NaN  Q2PN-AH88-6CK7         NaN
# 436552                     be:7d:2c:c5:42:f0  Q2PN-AH88-6CK7         NaN
# 436571  ea7860b8-a41d-4753-9667-40817b10f15c  Q2PN-AH88-6CK7         NaN
#
#        eventData_url eventData_server  eventData_categories  \
# 949              NaN              NaN                   NaN
# 1180             NaN              NaN                   NaN
# 1181             NaN              NaN                   NaN
# 1654             NaN              NaN                   NaN
# 2290             NaN              NaN                   NaN
# ...              ...              ...                   ...
# 436545           NaN              NaN                   NaN
# 436546           NaN              NaN                   NaN
# 436551           NaN              NaN                   NaN
# 436552           NaN              NaN                   NaN
# 436571           NaN              NaN                   NaN
#
#        eventData_Source_IP  eventData_Source_Port eventData_Destination_IP  \
# 949                    NaN                    NaN                      NaN
# 1180                   NaN                    NaN                      NaN
# 1181                   NaN                    NaN                      NaN
# 1654                   NaN                    NaN                      NaN
# 2290                   NaN                    NaN                      NaN
# ...                    ...                    ...                      ...
# 436545                 NaN                    NaN                      NaN
# 436546                 NaN                    NaN                      NaN
# 436551                 NaN                    NaN                      NaN
# 436552                 NaN                    NaN                      NaN
# 436571                 NaN                    NaN                      NaN
#
#         eventData_Destination_Port eventData_Protocol  eventData_NBAR_ID  \
# 949                            NaN                NaN                NaN
# 1180                           NaN                NaN                NaN
# 1181                           NaN                NaN                NaN
# 1654                           NaN                NaN                NaN
# 2290                           NaN                NaN                NaN
# ...                            ...                ...                ...
# 436545                         NaN                NaN                NaN
# 436546                         NaN                NaN                NaN
# 436551                         NaN                NaN                NaN
# 436552                         NaN                NaN                NaN
# 436571                         NaN                NaN                NaN
#
#        eventData_Classification eventData_Layer_7_firewall_rule  \
# 949                         NaN                             NaN
# 1180                        NaN                             NaN
# 1181                        NaN                             NaN
# 1654                        NaN                             NaN
# 2290                        NaN                             NaN
# ...                         ...                             ...
# 436545                      NaN                             NaN
# 436546                      NaN                             NaN
# 436551                      NaN                             NaN
# 436552                      NaN                             NaN
# 436571                      NaN                             NaN
#
#                          occurredAt
# 949     2022-09-01T20:49:14.018260Z
# 1180    2022-09-01T20:38:04.023041Z
# 1181    2022-09-01T20:37:14.023158Z
# 1654    2022-09-01T20:56:54.024899Z
# 2290    2022-09-27T22:12:46.497734Z
# ...                             ...
# 436545  2022-11-17T13:57:14.976617Z
# 436546  2022-11-17T13:57:14.976607Z
# 436551  2022-11-17T13:55:45.022083Z
# 436552  2022-11-17T13:55:45.022073Z
# 436571  2022-11-17T13:55:15.021446Z
#
# [5331 rows x 19 columns]
